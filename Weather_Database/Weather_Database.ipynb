# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
new = list(lat_lngs)

# %%
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in new:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | ambilobe
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | labuan
# Processing Record 7 of Set 1 | clyde river
# Processing Record 8 of Set 1 | upernavik
# Processing Record 9 of Set 1 | lujan
# Processing Record 10 of Set 1 | lompoc
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 1 | broome
# Processing Record 14 of Set 1 | kahului
# Processing Record 15 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | alice springs
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | liverpool
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 23 of Set 1 | sala
# Processing Record 24 of Set 1 | tasiilaq
# Processing Record 25 of Set 1 | nelson bay
# Processing Record 26 of Set 1 | hella
# Processing Record 27 of Set 1 | srednekolymsk
# Processing Record 28 of Set 1 | alyangula
# Processing Record 29 of Set 1 | san juan
# Processing Record 30 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | coulihaut
# City not found. Skipping...
# Processing Record 33 of Set 1 | kavaratti
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | bengkulu
# Processing Record 36 of Set 1 | tuatapere
# Processing Record 37 of Set 1 | manzhouli
# Processing Record 38 of Set 1 | palizada
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | cabedelo
# Processing Record 44 of Set 1 | cabo san lucas
# Processing Record 45 of Set 1 | puerto madero
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | saint anthony
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | iqaluit
# Processing Record 50 of Set 1 | shingu
# Processing Record 1 of Set 2 | alofi
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | bitung
# Processing Record 4 of Set 2 | belmonte
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | mahebourg
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | kieta
# Processing Record 9 of Set 2 | mount gambier
# Processing Record 10 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 2 | kalemie
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | punta arenas
# Processing Record 14 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 15 of Set 2 | tiznit
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | moerai
# Processing Record 18 of Set 2 | geraldton
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | taoudenni
# Processing Record 21 of Set 2 | yatou
# Processing Record 22 of Set 2 | sarahan
# Processing Record 23 of Set 2 | bazarnyy syzgan
# Processing Record 24 of Set 2 | rikitea
# Processing Record 25 of Set 2 | portobelo
# Processing Record 26 of Set 2 | collie
# Processing Record 27 of Set 2 | tiarei
# Processing Record 28 of Set 2 | tagab
# Processing Record 29 of Set 2 | batemans bay
# Processing Record 30 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | kloulklubed
# Processing Record 34 of Set 2 | puerto ayora
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | acapulco
# Processing Record 37 of Set 2 | kavieng
# Processing Record 38 of Set 2 | tukrah
# Processing Record 39 of Set 2 | aklavik
# Processing Record 40 of Set 2 | sokolo
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | banda aceh
# Processing Record 43 of Set 2 | victoria
# Processing Record 44 of Set 2 | vaini
# Processing Record 45 of Set 2 | roebourne
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | inirida
# Processing Record 48 of Set 2 | port lincoln
# Processing Record 49 of Set 2 | roald
# Processing Record 50 of Set 2 | mandalgovi
# Processing Record 1 of Set 3 | zhigansk
# Processing Record 2 of Set 3 | chumikan
# Processing Record 3 of Set 3 | odweyne
# Processing Record 4 of Set 3 | high level
# Processing Record 5 of Set 3 | sao filipe
# Processing Record 6 of Set 3 | valentin gomez farias
# Processing Record 7 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 3 | thompson
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | jinchang
# Processing Record 11 of Set 3 | ponta do sol
# Processing Record 12 of Set 3 | cooma
# Processing Record 13 of Set 3 | beringovskiy
# Processing Record 14 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 3 | bethel
# Processing Record 16 of Set 3 | saskylakh
# Processing Record 17 of Set 3 | kaitangata
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | butaritari
# Processing Record 20 of Set 3 | nikolskoye
# Processing Record 21 of Set 3 | panaba
# Processing Record 22 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 3 | cockburn town
# Processing Record 24 of Set 3 | poum
# Processing Record 25 of Set 3 | vila do maio
# Processing Record 26 of Set 3 | makakilo city
# Processing Record 27 of Set 3 | vilyuysk
# Processing Record 28 of Set 3 | clinton
# Processing Record 29 of Set 3 | linxia
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 3 | anadyr
# Processing Record 33 of Set 3 | port elizabeth
# Processing Record 34 of Set 3 | pitimbu
# Processing Record 35 of Set 3 | port hedland
# Processing Record 36 of Set 3 | dikson
# Processing Record 37 of Set 3 | luderitz
# Processing Record 38 of Set 3 | pisco
# Processing Record 39 of Set 3 | galegos
# Processing Record 40 of Set 3 | sao joao da barra
# Processing Record 41 of Set 3 | washington
# Processing Record 42 of Set 3 | faanui
# Processing Record 43 of Set 3 | kalmunai
# Processing Record 44 of Set 3 | andenes
# Processing Record 45 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 3 | biankouma
# Processing Record 47 of Set 3 | tevaitoa
# Processing Record 48 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 3 | constitucion
# Processing Record 50 of Set 3 | bullhead city
# Processing Record 1 of Set 4 | codrington
# Processing Record 2 of Set 4 | agua dulce
# Processing Record 3 of Set 4 | kruisfontein
# Processing Record 4 of Set 4 | rio gallegos
# Processing Record 5 of Set 4 | qaqortoq
# Processing Record 6 of Set 4 | qaanaaq
# Processing Record 7 of Set 4 | carnarvon
# Processing Record 8 of Set 4 | aquidauana
# Processing Record 9 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 4 | turukhansk
# Processing Record 11 of Set 4 | mucurapo
# Processing Record 12 of Set 4 | mwene-ditu
# Processing Record 13 of Set 4 | narsaq
# Processing Record 14 of Set 4 | kamaishi
# Processing Record 15 of Set 4 | graaff-reinet
# Processing Record 16 of Set 4 | sidney
# Processing Record 17 of Set 4 | san cristobal
# Processing Record 18 of Set 4 | la macarena
# Processing Record 19 of Set 4 | avera
# Processing Record 20 of Set 4 | dunedin
# Processing Record 21 of Set 4 | satun
# Processing Record 22 of Set 4 | ribeira grande
# Processing Record 23 of Set 4 | mar del plata
# Processing Record 24 of Set 4 | torbay
# Processing Record 25 of Set 4 | nome
# Processing Record 26 of Set 4 | rawson
# Processing Record 27 of Set 4 | port hardy
# Processing Record 28 of Set 4 | ostrovnoy
# Processing Record 29 of Set 4 | caravelas
# Processing Record 30 of Set 4 | kamenka
# Processing Record 31 of Set 4 | tucuman
# Processing Record 32 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | anqing
# Processing Record 35 of Set 4 | udachnyy
# Processing Record 36 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 37 of Set 4 | azare
# Processing Record 38 of Set 4 | jashpurnagar
# Processing Record 39 of Set 4 | laguna
# Processing Record 40 of Set 4 | nanortalik
# Processing Record 41 of Set 4 | boa vista
# Processing Record 42 of Set 4 | emba
# Processing Record 43 of Set 4 | salalah
# Processing Record 44 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 4 | pundaguitan
# Processing Record 46 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 4 | tuktoyaktuk
# Processing Record 49 of Set 4 | presidente dutra
# Processing Record 50 of Set 4 | ilulissat
# Processing Record 1 of Set 5 | talaya
# Processing Record 2 of Set 5 | hasaki
# Processing Record 3 of Set 5 | port blair
# Processing Record 4 of Set 5 | inhambane
# Processing Record 5 of Set 5 | saldanha
# Processing Record 6 of Set 5 | ahuimanu
# Processing Record 7 of Set 5 | de-kastri
# Processing Record 8 of Set 5 | ancud
# Processing Record 9 of Set 5 | xushan
# Processing Record 10 of Set 5 | puerto montt
# Processing Record 11 of Set 5 | goderich
# Processing Record 12 of Set 5 | rundu
# Processing Record 13 of Set 5 | sioux lookout
# Processing Record 14 of Set 5 | karatau
# Processing Record 15 of Set 5 | georgetown
# Processing Record 16 of Set 5 | bandarbeyla
# Processing Record 17 of Set 5 | talnakh
# Processing Record 18 of Set 5 | villamontes
# Processing Record 19 of Set 5 | bolshoye polpino
# City not found. Skipping...
# Processing Record 20 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 5 | vung tau
# Processing Record 22 of Set 5 | tigil
# Processing Record 23 of Set 5 | quatre cocos
# Processing Record 24 of Set 5 | baldone
# Processing Record 25 of Set 5 | sa kaeo
# Processing Record 26 of Set 5 | asino
# Processing Record 27 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 28 of Set 5 | cherskiy
# Processing Record 29 of Set 5 | beitbridge
# Processing Record 30 of Set 5 | muros
# Processing Record 31 of Set 5 | airai
# Processing Record 32 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 33 of Set 5 | axim
# Processing Record 34 of Set 5 | inta
# Processing Record 35 of Set 5 | guerrero negro
# Processing Record 36 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 5 | mehamn
# Processing Record 38 of Set 5 | umm lajj
# Processing Record 39 of Set 5 | loreto
# Processing Record 40 of Set 5 | neuquen
# Processing Record 41 of Set 5 | ahipara
# Processing Record 42 of Set 5 | salinopolis
# Processing Record 43 of Set 5 | leningradskiy
# Processing Record 44 of Set 5 | abu samrah
# Processing Record 45 of Set 5 | wanning
# Processing Record 46 of Set 5 | abhar
# Processing Record 47 of Set 5 | kungurtug
# Processing Record 48 of Set 5 | kampong thum
# Processing Record 49 of Set 5 | tanout
# Processing Record 50 of Set 5 | harrisburg
# Processing Record 1 of Set 6 | sicuani
# Processing Record 2 of Set 6 | sterling
# Processing Record 3 of Set 6 | new ulm
# Processing Record 4 of Set 6 | kerman
# Processing Record 5 of Set 6 | pucallpa
# Processing Record 6 of Set 6 | orodara
# Processing Record 7 of Set 6 | norman wells
# Processing Record 8 of Set 6 | adamovka
# Processing Record 9 of Set 6 | esperance
# Processing Record 10 of Set 6 | chuy
# Processing Record 11 of Set 6 | nola
# Processing Record 12 of Set 6 | zacualpan
# Processing Record 13 of Set 6 | zafra
# Processing Record 14 of Set 6 | crossfield
# Processing Record 15 of Set 6 | ukiah
# Processing Record 16 of Set 6 | merauke
# Processing Record 17 of Set 6 | plettenberg bay
# Processing Record 18 of Set 6 | tefe
# Processing Record 19 of Set 6 | kudahuvadhoo
# Processing Record 20 of Set 6 | souillac
# Processing Record 21 of Set 6 | kristiinankaupunki
# Processing Record 22 of Set 6 | alihe
# Processing Record 23 of Set 6 | kindersley
# Processing Record 24 of Set 6 | bahia blanca
# Processing Record 25 of Set 6 | zhenlai
# Processing Record 26 of Set 6 | longyearbyen
# Processing Record 27 of Set 6 | yeppoon
# Processing Record 28 of Set 6 | presidencia roque saenz pena
# Processing Record 29 of Set 6 | angangueo
# Processing Record 30 of Set 6 | dhidhdhoo
# Processing Record 31 of Set 6 | havre-saint-pierre
# Processing Record 32 of Set 6 | vostok
# Processing Record 33 of Set 6 | saint-philippe
# Processing Record 34 of Set 6 | saint-pierre
# Processing Record 35 of Set 6 | ossipee
# Processing Record 36 of Set 6 | klaksvik
# Processing Record 37 of Set 6 | matara
# Processing Record 38 of Set 6 | dingle
# Processing Record 39 of Set 6 | frekhaug
# Processing Record 40 of Set 6 | uzhur
# Processing Record 41 of Set 6 | mount isa
# Processing Record 42 of Set 6 | cidreira
# Processing Record 43 of Set 6 | pandan
# Processing Record 44 of Set 6 | petrivka
# Processing Record 45 of Set 6 | atikokan
# Processing Record 46 of Set 6 | yaan
# Processing Record 47 of Set 6 | fukue
# Processing Record 48 of Set 6 | labuhan
# Processing Record 49 of Set 6 | vestmannaeyjar
# Processing Record 50 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 7 | coquimbo
# Processing Record 2 of Set 7 | sayyan
# Processing Record 3 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 7 | trairi
# Processing Record 5 of Set 7 | comodoro rivadavia
# Processing Record 6 of Set 7 | nhulunbuy
# Processing Record 7 of Set 7 | kulhudhuffushi
# Processing Record 8 of Set 7 | baiquan
# Processing Record 9 of Set 7 | kiruna
# Processing Record 10 of Set 7 | bilma
# Processing Record 11 of Set 7 | sept-iles
# Processing Record 12 of Set 7 | olafsvik
# Processing Record 13 of Set 7 | natal
# Processing Record 14 of Set 7 | san juan ixcoy
# Processing Record 15 of Set 7 | aquiraz
# Processing Record 16 of Set 7 | manicore
# Processing Record 17 of Set 7 | portland
# Processing Record 18 of Set 7 | katobu
# Processing Record 19 of Set 7 | coihaique
# Processing Record 20 of Set 7 | walvis bay
# Processing Record 21 of Set 7 | biltine
# Processing Record 22 of Set 7 | murud
# Processing Record 23 of Set 7 | rostaq
# City not found. Skipping...
# Processing Record 24 of Set 7 | provideniya
# Processing Record 25 of Set 7 | lagos
# Processing Record 26 of Set 7 | nenjiang
# Processing Record 27 of Set 7 | pokhara
# Processing Record 28 of Set 7 | talcahuano
# Processing Record 29 of Set 7 | zhangye
# Processing Record 30 of Set 7 | sitka
# Processing Record 31 of Set 7 | paka
# Processing Record 32 of Set 7 | parsabad
# Processing Record 33 of Set 7 | opuwo
# Processing Record 34 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 7 | prabumulih
# Processing Record 36 of Set 7 | saint george
# Processing Record 37 of Set 7 | jacareacanga
# Processing Record 38 of Set 7 | mikun
# Processing Record 39 of Set 7 | kambarka
# Processing Record 40 of Set 7 | adrar
# Processing Record 41 of Set 7 | krasnoselkup
# Processing Record 42 of Set 7 | biaora
# Processing Record 43 of Set 7 | hovd
# Processing Record 44 of Set 7 | les cayes
# Processing Record 45 of Set 7 | fortuna
# Processing Record 46 of Set 7 | ponsacco
# Processing Record 47 of Set 7 | xunchang
# Processing Record 48 of Set 7 | bogorodskoye
# Processing Record 49 of Set 7 | ziarat
# Processing Record 50 of Set 7 | ngunguru
# Processing Record 1 of Set 8 | puerto escondido
# Processing Record 2 of Set 8 | tabou
# Processing Record 3 of Set 8 | limenaria
# Processing Record 4 of Set 8 | hobyo
# Processing Record 5 of Set 8 | teya
# Processing Record 6 of Set 8 | riyadh
# Processing Record 7 of Set 8 | dukat
# Processing Record 8 of Set 8 | zeljezno polje
# Processing Record 9 of Set 8 | kozhva
# Processing Record 10 of Set 8 | oksfjord
# Processing Record 11 of Set 8 | asfi
# Processing Record 12 of Set 8 | kisangani
# Processing Record 13 of Set 8 | alta floresta
# Processing Record 14 of Set 8 | vanimo
# Processing Record 15 of Set 8 | bayburt
# Processing Record 16 of Set 8 | sjenica
# Processing Record 17 of Set 8 | sao jose da coroa grande
# Processing Record 18 of Set 8 | miles city
# Processing Record 19 of Set 8 | aasiaat
# Processing Record 20 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 8 | richards bay
# Processing Record 22 of Set 8 | totma
# Processing Record 23 of Set 8 | myitkyina
# Processing Record 24 of Set 8 | solnechnyy
# Processing Record 25 of Set 8 | ambon
# Processing Record 26 of Set 8 | dudinka
# Processing Record 27 of Set 8 | viedma
# Processing Record 28 of Set 8 | hofn
# Processing Record 29 of Set 8 | vestmanna
# Processing Record 30 of Set 8 | kem
# Processing Record 31 of Set 8 | raudeberg
# Processing Record 32 of Set 8 | dothan
# Processing Record 33 of Set 8 | sistranda
# Processing Record 34 of Set 8 | illela
# Processing Record 35 of Set 8 | winslow
# Processing Record 36 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 8 | lokosovo
# Processing Record 38 of Set 8 | general roca
# Processing Record 39 of Set 8 | yulara
# Processing Record 40 of Set 8 | bam
# Processing Record 41 of Set 8 | fayaoue
# Processing Record 42 of Set 8 | tezu
# Processing Record 43 of Set 8 | colesberg
# Processing Record 44 of Set 8 | muriwai beach
# Processing Record 45 of Set 8 | karratha
# Processing Record 46 of Set 8 | monteagudo
# Processing Record 47 of Set 8 | pietersburg
# Processing Record 48 of Set 8 | rehoboth
# Processing Record 49 of Set 8 | atar
# Processing Record 50 of Set 8 | sembe
# Processing Record 1 of Set 9 | godda
# Processing Record 2 of Set 9 | grindavik
# Processing Record 3 of Set 9 | kovdor
# Processing Record 4 of Set 9 | wilmington
# Processing Record 5 of Set 9 | chapleau
# Processing Record 6 of Set 9 | honjo
# Processing Record 7 of Set 9 | akdepe
# Processing Record 8 of Set 9 | poitiers
# Processing Record 9 of Set 9 | fort nelson
# Processing Record 10 of Set 9 | fort frances
# Processing Record 11 of Set 9 | the valley
# Processing Record 12 of Set 9 | vardo
# Processing Record 13 of Set 9 | zgierz
# Processing Record 14 of Set 9 | sola
# Processing Record 15 of Set 9 | severo-kurilsk
# Processing Record 16 of Set 9 | kampene
# Processing Record 17 of Set 9 | maldonado
# Processing Record 18 of Set 9 | benghazi
# Processing Record 19 of Set 9 | jaguarao
# Processing Record 20 of Set 9 | sur
# Processing Record 21 of Set 9 | praia da vitoria
# Processing Record 22 of Set 9 | lavrentiya
# Processing Record 23 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 9 | helena
# Processing Record 26 of Set 9 | san andres
# Processing Record 27 of Set 9 | vao
# Processing Record 28 of Set 9 | markova
# Processing Record 29 of Set 9 | parrita
# Processing Record 30 of Set 9 | sao joao da ponte
# Processing Record 31 of Set 9 | flinders
# Processing Record 32 of Set 9 | cayenne
# Processing Record 33 of Set 9 | la ronge
# Processing Record 34 of Set 9 | wladyslawowo
# Processing Record 35 of Set 9 | aden
# Processing Record 36 of Set 9 | la candelaria
# Processing Record 37 of Set 9 | general bravo
# Processing Record 38 of Set 9 | okhotsk
# Processing Record 39 of Set 9 | matagami
# Processing Record 40 of Set 9 | itoman
# Processing Record 41 of Set 9 | hutchinson
# Processing Record 42 of Set 9 | ban tak
# Processing Record 43 of Set 9 | nalbari
# Processing Record 44 of Set 9 | uribia
# Processing Record 45 of Set 9 | shangqiu
# Processing Record 46 of Set 9 | khanpur
# Processing Record 47 of Set 9 | beloha
# Processing Record 48 of Set 9 | irati
# Processing Record 49 of Set 9 | nalut
# Processing Record 50 of Set 9 | san borja
# Processing Record 1 of Set 10 | palembang
# Processing Record 2 of Set 10 | svetlaya
# Processing Record 3 of Set 10 | tautira
# Processing Record 4 of Set 10 | orissaare
# Processing Record 5 of Set 10 | mullingar
# Processing Record 6 of Set 10 | haines junction
# Processing Record 7 of Set 10 | ammon
# Processing Record 8 of Set 10 | te anau
# Processing Record 9 of Set 10 | mangrol
# Processing Record 10 of Set 10 | bernburg
# Processing Record 11 of Set 10 | lichinga
# Processing Record 12 of Set 10 | malaga
# Processing Record 13 of Set 10 | amantea
# Processing Record 14 of Set 10 | dutse
# Processing Record 15 of Set 10 | castleblayney
# Processing Record 16 of Set 10 | ribeira brava
# Processing Record 17 of Set 10 | greenlaw
# Processing Record 18 of Set 10 | khorixas
# Processing Record 19 of Set 10 | santa lucia
# Processing Record 20 of Set 10 | mocajuba
# Processing Record 21 of Set 10 | wajima
# Processing Record 22 of Set 10 | saint-georges
# Processing Record 23 of Set 10 | caernarfon
# Processing Record 24 of Set 10 | segovia
# Processing Record 25 of Set 10 | kobelyaky
# Processing Record 26 of Set 10 | pinillos
# Processing Record 27 of Set 10 | sanson
# Processing Record 28 of Set 10 | sar-e pul
# Processing Record 29 of Set 10 | hornepayne
# Processing Record 30 of Set 10 | salina
# Processing Record 31 of Set 10 | cap malheureux
# Processing Record 32 of Set 10 | sargatskoye
# Processing Record 33 of Set 10 | kenai
# Processing Record 34 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 10 | faya
# Processing Record 36 of Set 10 | babu
# Processing Record 37 of Set 10 | shenzhen
# Processing Record 38 of Set 10 | orange cove
# Processing Record 39 of Set 10 | dembi dolo
# Processing Record 40 of Set 10 | hauterive
# Processing Record 41 of Set 10 | hinton
# Processing Record 42 of Set 10 | hay river
# Processing Record 43 of Set 10 | komsomolskiy
# Processing Record 44 of Set 10 | khorramshahr
# Processing Record 45 of Set 10 | westport
# Processing Record 46 of Set 10 | padang
# Processing Record 47 of Set 10 | meilu
# City not found. Skipping...
# Processing Record 48 of Set 10 | rudnya
# Processing Record 49 of Set 10 | roma
# Processing Record 50 of Set 10 | igunga
# Processing Record 1 of Set 11 | lake cowichan
# Processing Record 2 of Set 11 | barda
# Processing Record 3 of Set 11 | sao felix do xingu
# Processing Record 4 of Set 11 | masterton
# Processing Record 5 of Set 11 | gillette
# Processing Record 6 of Set 11 | taywarah
# Processing Record 7 of Set 11 | ila
# Processing Record 8 of Set 11 | nicoya
# Processing Record 9 of Set 11 | thunder bay
# Processing Record 10 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 11 | ler
# Processing Record 12 of Set 11 | baruun-urt
# Processing Record 13 of Set 11 | tiruchchendur
# Processing Record 14 of Set 11 | kurkino
# Processing Record 15 of Set 11 | rafaela
# Processing Record 16 of Set 11 | port keats
# Processing Record 17 of Set 11 | hami
# Processing Record 18 of Set 11 | praia
# Processing Record 19 of Set 11 | saint-paul
# Processing Record 20 of Set 11 | boulder
# Processing Record 21 of Set 11 | alamosa
# Processing Record 22 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 23 of Set 11 | edd
# Processing Record 24 of Set 11 | kasongo
# Processing Record 25 of Set 11 | verkhnyaya inta
# Processing Record 26 of Set 11 | san patricio
# Processing Record 27 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 28 of Set 11 | hambantota
# Processing Record 29 of Set 11 | kirillov
# Processing Record 30 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 31 of Set 11 | cabugao
# Processing Record 32 of Set 11 | bacia
# Processing Record 33 of Set 11 | rangapara
# Processing Record 34 of Set 11 | aitape
# Processing Record 35 of Set 11 | bathsheba
# Processing Record 36 of Set 11 | moose factory
# Processing Record 37 of Set 11 | jardim
# Processing Record 38 of Set 11 | urengoy
# Processing Record 39 of Set 11 | karaton
# Processing Record 40 of Set 11 | dalvik
# Processing Record 41 of Set 11 | nuuk
# Processing Record 42 of Set 11 | mackenzie
# Processing Record 43 of Set 11 | arcachon
# Processing Record 44 of Set 11 | kodinsk
# Processing Record 45 of Set 11 | kaeo
# Processing Record 46 of Set 11 | mhango
# Processing Record 47 of Set 11 | fallon
# Processing Record 48 of Set 11 | katsuura
# Processing Record 49 of Set 11 | olovyannaya
# Processing Record 50 of Set 11 | bunia
# Processing Record 1 of Set 12 | lazaro cardenas
# Processing Record 2 of Set 12 | tres lagoas
# Processing Record 3 of Set 12 | weatherford
# Processing Record 4 of Set 12 | oranjemund
# Processing Record 5 of Set 12 | san quintin
# Processing Record 6 of Set 12 | hongjiang
# Processing Record 7 of Set 12 | sosnovo-ozerskoye
# Processing Record 8 of Set 12 | upata
# Processing Record 9 of Set 12 | burnie
# Processing Record 10 of Set 12 | mount pleasant
# Processing Record 11 of Set 12 | agadez
# Processing Record 12 of Set 12 | lorengau
# Processing Record 13 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 12 | nizwa
# Processing Record 15 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 16 of Set 12 | shelburne
# Processing Record 17 of Set 12 | mulege
# Processing Record 18 of Set 12 | cardinal
# Processing Record 19 of Set 12 | booue
# Processing Record 20 of Set 12 | meulaboh
# Processing Record 21 of Set 12 | yar-sale
# Processing Record 22 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 23 of Set 12 | lubao
# Processing Record 24 of Set 12 | iquitos
# Processing Record 25 of Set 12 | dharapuram
# Processing Record 26 of Set 12 | ha
# City not found. Skipping...
# Processing Record 27 of Set 12 | maarianhamina
# Processing Record 28 of Set 12 | namatanai
# Processing Record 29 of Set 12 | paamiut
# Processing Record 30 of Set 12 | khani
# Processing Record 31 of Set 12 | kununurra
# Processing Record 32 of Set 12 | vila franca do campo
# Processing Record 33 of Set 12 | mumford
# Processing Record 34 of Set 12 | madang
# Processing Record 35 of Set 12 | assiniboia
# Processing Record 36 of Set 12 | verkhnevilyuysk
# Processing Record 37 of Set 12 | flin flon
# Processing Record 38 of Set 12 | winchester
# Processing Record 39 of Set 12 | hamilton
# Processing Record 40 of Set 12 | sungaipenuh
# Processing Record 41 of Set 12 | namibe
# Processing Record 42 of Set 12 | vicosa
# Processing Record 43 of Set 12 | gizo
# Processing Record 44 of Set 12 | mulbagal
# Processing Record 45 of Set 12 | dubai
# Processing Record 46 of Set 12 | orcopampa
# Processing Record 47 of Set 12 | tulun
# Processing Record 48 of Set 12 | iaciara
# Processing Record 49 of Set 12 | begoro
# Processing Record 50 of Set 12 | fresnillo
# Processing Record 1 of Set 13 | ranong
# Processing Record 2 of Set 13 | gornoye loo
# Processing Record 3 of Set 13 | broken hill
# Processing Record 4 of Set 13 | huadian
# Processing Record 5 of Set 13 | villaviciosa
# Processing Record 6 of Set 13 | berlevag
# Processing Record 7 of Set 13 | jiuquan
# Processing Record 8 of Set 13 | coetupo
# City not found. Skipping...
# Processing Record 9 of Set 13 | santa cruz de tenerife
# Processing Record 10 of Set 13 | gat
# Processing Record 11 of Set 13 | ascension
# Processing Record 12 of Set 13 | carutapera
# Processing Record 13 of Set 13 | maceio
# Processing Record 14 of Set 13 | korla
# Processing Record 15 of Set 13 | chifeng
# Processing Record 16 of Set 13 | linares
# Processing Record 17 of Set 13 | joshimath
# Processing Record 18 of Set 13 | naze
# Processing Record 19 of Set 13 | porto seguro
# Processing Record 20 of Set 13 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 21 of Set 13 | fare
# Processing Record 22 of Set 13 | rio de janeiro
# Processing Record 23 of Set 13 | yenangyaung
# Processing Record 24 of Set 13 | kaseda
# Processing Record 25 of Set 13 | yongan
# Processing Record 26 of Set 13 | ajdabiya
# Processing Record 27 of Set 13 | san dionisio del mar
# Processing Record 28 of Set 13 | andra
# Processing Record 29 of Set 13 | coxim
# Processing Record 30 of Set 13 | finschhafen
# Processing Record 31 of Set 13 | oudtshoorn
# Processing Record 32 of Set 13 | sechura
# Processing Record 33 of Set 13 | mezen
# Processing Record 34 of Set 13 | coahuayana
# Processing Record 35 of Set 13 | zhenhai
# Processing Record 36 of Set 13 | rusape
# Processing Record 37 of Set 13 | omsukchan
# Processing Record 38 of Set 13 | shimoda
# Processing Record 39 of Set 13 | altamont
# Processing Record 40 of Set 13 | concepcion
# Processing Record 41 of Set 13 | sabang
# Processing Record 42 of Set 13 | noumea
# Processing Record 43 of Set 13 | clarence town
# Processing Record 44 of Set 13 | lata
# Processing Record 45 of Set 13 | tabas
# Processing Record 46 of Set 13 | casablanca
# Processing Record 47 of Set 13 | hervey bay
# Processing Record 48 of Set 13 | gunnedah
# Processing Record 49 of Set 13 | muzhi
# Processing Record 50 of Set 13 | tevriz
# Processing Record 1 of Set 14 | grand gaube
# Processing Record 2 of Set 14 | saint-joseph
# Processing Record 3 of Set 14 | saint-francois
# Processing Record 4 of Set 14 | todos santos
# Processing Record 5 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 6 of Set 14 | takoradi
# Processing Record 7 of Set 14 | wharton
# Processing Record 8 of Set 14 | garowe
# Processing Record 9 of Set 14 | prado
# Processing Record 10 of Set 14 | tucuma
# Processing Record 11 of Set 14 | teguise
# Processing Record 12 of Set 14 | ignacio zaragoza
# Processing Record 13 of Set 14 | fairbanks
# Processing Record 14 of Set 14 | cozumel
# Processing Record 15 of Set 14 | kralendijk
# Processing Record 16 of Set 14 | mutenice
# Processing Record 17 of Set 14 | magadan
# Processing Record 18 of Set 14 | husavik
# Processing Record 19 of Set 14 | isangel
# Processing Record 20 of Set 14 | white rock
# Processing Record 21 of Set 14 | male
# Processing Record 22 of Set 14 | camacha
# Processing Record 23 of Set 14 | antofagasta
# Processing Record 24 of Set 14 | vegreville
# Processing Record 25 of Set 14 | clovis
# Processing Record 26 of Set 14 | shimanovsk
# Processing Record 27 of Set 14 | morehead
# Processing Record 28 of Set 14 | ugoofaaru
# Processing Record 29 of Set 14 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 14 | tabukiniberu
# City not found. Skipping...
# Processing Record 31 of Set 14 | arkadak
# Processing Record 32 of Set 14 | manokwari
# Processing Record 33 of Set 14 | trud
# Processing Record 34 of Set 14 | necochea
# Processing Record 35 of Set 14 | prince rupert
# Processing Record 36 of Set 14 | chernyshevskiy
# Processing Record 37 of Set 14 | strezhevoy
# Processing Record 38 of Set 14 | inverness
# Processing Record 39 of Set 14 | cacu
# Processing Record 40 of Set 14 | waipawa
# Processing Record 41 of Set 14 | shymkent
# Processing Record 42 of Set 14 | ketchikan
# Processing Record 43 of Set 14 | agadir
# Processing Record 44 of Set 14 | victor harbor
# Processing Record 45 of Set 14 | solikamsk
# Processing Record 46 of Set 14 | horta
# Processing Record 47 of Set 14 | maracaju
# Processing Record 48 of Set 14 | gusinoye ozero
# Processing Record 49 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 50 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 1 of Set 15 | plattsburgh
# Processing Record 2 of Set 15 | podgornoye
# Processing Record 3 of Set 15 | izumo
# Processing Record 4 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 15 | nyurba
# Processing Record 6 of Set 15 | port macquarie
# Processing Record 7 of Set 15 | bilibino
# Processing Record 8 of Set 15 | waddan
# Processing Record 9 of Set 15 | lucea
# Processing Record 10 of Set 15 | vila velha
# Processing Record 11 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 12 of Set 15 | bereda
# Processing Record 13 of Set 15 | dubbo
# Processing Record 14 of Set 15 | chingola
# Processing Record 15 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 16 of Set 15 | ambulu
# Processing Record 17 of Set 15 | touros
# Processing Record 18 of Set 15 | presidente epitacio
# Processing Record 19 of Set 15 | liuhe
# Processing Record 20 of Set 15 | pangnirtung
# Processing Record 21 of Set 15 | gandajika
# Processing Record 22 of Set 15 | emerald
# Processing Record 23 of Set 15 | gouyave
# Processing Record 24 of Set 15 | port-gentil
# Processing Record 25 of Set 15 | pertuis
# Processing Record 26 of Set 15 | imst
# Processing Record 27 of Set 15 | jumla
# Processing Record 28 of Set 15 | itarema
# Processing Record 29 of Set 15 | calabozo
# Processing Record 30 of Set 15 | wagga wagga
# Processing Record 31 of Set 15 | pryozerne
# Processing Record 32 of Set 15 | brae
# Processing Record 33 of Set 15 | dongsheng
# Processing Record 34 of Set 15 | lasa
# Processing Record 35 of Set 15 | blonduos
# City not found. Skipping...
# Processing Record 36 of Set 15 | zhizdra
# Processing Record 37 of Set 15 | linhai
# Processing Record 38 of Set 15 | tucumcari
# Processing Record 39 of Set 15 | san fernando
# Processing Record 40 of Set 15 | acarau
# Processing Record 41 of Set 15 | sanming
# Processing Record 42 of Set 15 | santarem
# Processing Record 43 of Set 15 | lerwick
# Processing Record 44 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 45 of Set 15 | paso de los toros
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 688

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Hobart      AU -42.8794  147.3294     53.26        77
# 1          Port Alfred      ZA -33.5906   26.8910     79.41        73
# 2            Cape Town      ZA -33.9258   18.4232     87.12        50
# 3             Ambilobe      MG -13.2000   49.0500     80.78        82
# 4            Busselton      AU -33.6500  115.3333     56.08        77
# ..                 ...     ...      ...       ...       ...       ...
# 683             Acarau      BR  -2.8856  -40.1200     86.41        61
# 684            Sanming      CN  26.2486  117.6186     51.58        94
# 685           Santarem      BR  -2.4431  -54.7083     77.13       100
# 686            Lerwick      GB  60.1545   -1.1494     37.40        76
# 687  Paso De Los Toros      UY -32.8167  -56.5167     68.34        44
#
#      Cloudiness  Wind Speed   Current Description
# 0            51        0.00         broken clouds
# 1             0       31.81             clear sky
# 2             0       21.85             clear sky
# 3            15        8.75            light rain
# 4            65       15.21         broken clouds
# ..          ...         ...                   ...
# 683          39       14.12      scattered clouds
# 684         100        2.77            light rain
# 685         100        8.05  heavy intensity rain
# 686         100       28.03       overcast clouds
# 687          39       15.82      scattered clouds
#
# [688 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
